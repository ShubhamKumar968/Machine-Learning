# %%
import math

print(math.e)
print(math.pi)
print(math.factorial(5))
a=math.ceil(6.3)
print(a)

print (math.floor(6.9))

print(math.sqrt(9))
# Out:
# 2.718281828459045
# 3.141592653589793
# 120
# 7
# 6
# 3.0

# %%
import random

a=random.randint(1,100)
print(a)

b=[3,5,6,9]
random.shuffle(b)
print(b)
# Out:
# 13
# [6, 5, 9, 3]

# %%
import time

print (time.ctime())

print(time.time())

print('hello')
time.sleep(2)
print('world')
# Out:
# Fri Apr  3 16:46:38 2026
# 1775214998.5349996
# hello
# world

# %%
import os

print(os.getcwd())

print(os.listdir())
# Out:
# c:\Users\HP\Desktop\Machine Learning\1Python
# ['01_print.ipynb', '02_dataTypes.ipynb', '03_comments.ipynb', '04_variables.ipynb', '05_keywords.ipynb', '06_takingUserInput.ipynb', '07_typeConversion.ipynb', '08_literals.ipynb', '09_operators.ipynb', '10_ifElse.ipynb', '11_whileLoops.ipynb', '12_randomLibrary.ipynb', '13_guessingGame.ipynb', '14_range.ipynb', '15_forLoop.ipynb', '16_breakContinuePass.ipynb', '17_builtInFunction.ipynb', '18_modules(library).ipynb']
