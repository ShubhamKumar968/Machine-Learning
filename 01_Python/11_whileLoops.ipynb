# %%
#python me keval while and for loop hota hai

#print the table of any given number.
number= int( input("Enter the Number: "))

i=1
while i<=10 :
    print(number, "X", i ,"=" , number*i)
    i+=1
# Out:
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100
