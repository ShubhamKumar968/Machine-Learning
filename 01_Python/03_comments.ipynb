# %%
#comments => it is piece of code which is not executable by compiler

#comments improve the readability of the code

#(1). Single line Comment

#print('hii')

'''(2) Multiline Comment'''

'''print('hello')'''
