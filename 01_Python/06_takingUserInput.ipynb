# %%
            # Taking user input

#input() -> can take atmost one argument, It takes input from keyboard
# It always return 'str type' value.

input(prompt="What's Your name? ")
# Out:
# 'Shubham'

# %%
#program to add two numbers

first_num= input("Enter the first number: ")
second_num= input("Enter the second number: ")
print("first Num: ",first_num)
print("Second Num: ",second_num)
print("Sum is: " , (first_num + second_num)) #concatenation due to string type
print(type(first_num))
# Out:
# first Num:  4
# Second Num:  6
# Sum is:  46
# <class 'str'>
