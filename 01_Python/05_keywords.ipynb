# %%
#python is case sensitive language (i.e, there is difference in lower and uppercase)

#keywords are predefined reseved words

# keywords are not used in variable name 
import keyword
print('There are total' ,len(keyword.kwlist),"Keywords in Python")
print(keyword.kwlist)
# Out:
# There are total 35 Keywords in Python
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#identifiers  :- it is the name used to identify a variable, function, class, object.

#Naming of variables:

#(1)can only start with an alphabet or _
#(2)followed by zero or more letters, digits, _.
#(3)keywords can't used as an identifiers

1name='string'
namA$='shubham'
# Out:
#   Cell In[4], line 9
#     1name='string'
#     ^
# SyntaxError: invalid decimal literal
