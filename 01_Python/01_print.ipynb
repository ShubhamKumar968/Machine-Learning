# %%
                     #Printing anything

print('Hello world!')
# Out:
# Hello world!

# %%
print(9.4)
# Out:
# 9.4

# %%
print(True)
# Out:
# True

# %%
print('JPMorgan Chase & Co.' , 'Fastenel' , 'Visa' , 'Cisco' ,'Oracle' , 'Uber' , 'Amazon');
# Out:
# JPMorgan Chase & Co. Fastenel Visa Cisco Oracle Uber Amazon

# %%
print('Shubham' , 9.3 , 18 , 'LPA' , True)
# Out:
# Shubham 9.3 18 LPA True

# %%
print('Python','Cpp','Backend','SQL' ,'DSA', sep='/')
# Out:
# Python/Cpp/Backend/SQL/DSA

# %%
# print() -> bydefault jo bhi data print karta hai, uske end me ek newline character add kar deta hai.
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('Hello' , end=' ')
print('World')
# Out:
# Hello World
